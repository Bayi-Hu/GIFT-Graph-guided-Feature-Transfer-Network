# %%
#-*- coding:utf-8 -*-
import pandas as pd
import collections
import numpy as np
import re

def load_list(fname):
    list_ = []
    with open(fname, encoding="utf-8") as f:
        for line in f.readlines():
            list_.append(line.strip())
    return list_


input_dir = './'

# read logs
ui_data = pd.read_csv(input_dir+'user_book.txt', names=['user','item','rating'], sep='\t',engine='python')
# ui_data.loc[ui_data[ui_data.rating < 4].index, 'label'] = "0"
# ui_data.loc[ui_data[ui_data.rating >= 4].index, 'label'] = "1"
# ui_data = ui_data.astype("str")


# read item/user feature
ul = pd.read_csv(input_dir+'user_location.txt', names=['user','location'], sep='\t',engine='python')
ug = pd.read_csv(input_dir+'user_group.txt', names=['user','group'], sep='\t', engine='python')

ba = pd.read_csv(input_dir+'book_author.txt', names=['book','author'], sep='\t',engine='python')
bp = pd.read_csv(input_dir+'book_publisher.txt', names=['book','publisher'], sep='\t',engine='python')
by = pd.read_csv(input_dir+'book_year.txt', names=['book','year'], sep='\t',engine='python')

user_list = list(set(ui_data.user) & set(ul.user))
item_list = list(set(ui_data.item) & ((set(ba.book) & set(bp.book))) & set(by.book))

print(len(user_list), len(item_list))

location_list = list(set(ul[ul.user.isin(user_list)].location))
group_list = list(set(ug[ug.user.isin(user_list)].group))
publisher_list = list(set(bp[bp.book.isin(item_list)].publisher))
author_list = list(set(ba[ba.book.isin(item_list)].author))
len(location_list), len(group_list), len(publisher_list), len(author_list)
# Out:
# 10592 20934
# (453, 2936, 1698, 10544)

# %%
# user_feat
user_feat = pd.merge(left=ul, right=ug, on="user", how="inner")

# %%
ul.shape
# Out:
# (10592, 2)

# %%
ug.group.values.astype(str)
# Out:
# array(['232', '666', '226', ..., '2882', '2556', '54'], dtype='<U21')

# %%
def udf(df):
    return np.array([[df.iloc[0]["user"], "".join(df.group.values.astype(str))]])

ug_ = ug.groupby(["user"]).apply(udf)

# %%
np.concatenate(ug_.values,axis=0)
# Out:
# array([['1',
#         '1663\x021461\x0222\x02238\x02106\x02716\x02207\x02190\x02245\x02112\x02132\x022720\x02290\x02252\x022422\x021759\x021864\x022661\x02188\x021529\x027\x021114\x02464\x02553\x02659\x021659\x02507\x0241\x02153\x021097\x0249\x02447\x02144\x02841\x021316\x0253\x022295\x024\x02374\x0237\x0256\x028\x021299\x021893\x02472\x022455\x025\x0245\x022245\x02201\x02767\x02703\x0242\x0272\x022893\x02644\x026\x021498\x02324\x02477\x022606\x02149\x02874\x021212\x022\x0255\x02715\x02168\x02648\x021343\x02237\x021680\x02723\x02696\x02364\x0291\x02118\x021\x022165\x021238\x02584\x02661\x021831\x02204\x02539\x0212\x022810\x0221\x021049\x0280\x0228\x02113\x0213\x021617\x021866\x02457\x02101\x0218\x02386\x023\x02241\x0217\x02230\x0223\x022913\x0254'],
#        ['2',
#         '9\x02124\x022284\x02525\x0273\x02519\x021774\x021243\x0229\x02405\x02183\x0248\x02446\x02834\x02870\x022518\x02143\x022\x02166\x02310\x0231\x02369\x02894\x021\x02115\x022651\x0233\x0212\x021125\x0215\x02750\x0218\x023\x02350'],
#        ['3',
#         '43\x021026\x02698\x02403\x022010\x021041\x0273\x021969\x02663\x0262\x021547\x0239\x02327\x02475\x0270\x021461\x02990\x0261\x02828\x021967\x02274\x021587\x02436\x02609\x021085\x0229\x02318\x02399\x02599\x02263\x02629\x0266\x02117\x021062\x021107\x0219\x0275\x02281\x0248\x021061\x0287\x0249\x02365\x02769\x02420\x02242\x02331\x02244\x02103\x02314\x021741\x022063\x022817\x024\x021481\x02522\x02174\x02197\x02116\x0288\x0257\x022519\x02730\x02215\x021189\x02261\x02818\x0258\x02138\x02134\x02909\x02713\x02329\x02502\x0210\x0255\x02358\x021951\x021333\x021321\x02262\x0286\x02283\x0231\x02559\x02319\x02856\x021\x021753\x02728\x022430\x0292\x0214\x022178\x02265\x02823\x02371\x02181\x02930\x02620\x02880\x023\x021751\x02192\x02350\x021100\x022130\x0254'],
#        ...,
#        ['13022',
#         '282\x022093\x02139\x02356\x02190\x022208\x021944\x02301\x021672\x02811\x02260\x021294\x02191\x02303\x021671\x021348\x02306\x02111\x0293\x02120\x02105\x021173\x02659\x0274\x022066\x02302\x02135\x02291\x022657\x02147\x021836\x02331\x021304\x0253\x021581\x021329\x02786\x02346\x028\x025\x021322\x021579\x02444\x026\x02393\x022137\x021246\x021823\x02602\x022202\x02134\x02148\x0255\x021122\x021619\x02592\x021059\x021230\x02218\x021611\x02676\x02445\x0286\x021229\x021856\x02167\x02364\x021557\x021253\x02118\x021972\x021\x022652\x02921\x02981\x0212\x0221\x0280\x0228\x02500\x02898\x022180\x0214\x0225\x02457\x0285\x021407\x023\x0217\x022467\x021426\x02304\x02152\x02511\x02591\x0234\x0230\x0220'],
#        ['13023',
#         '76\x021225\x0273\x02431\x02258\x02932\x021142\x0239\x022043\x0270\x021485\x021808\x021762\x02562\x021168\x02716\x02207\x02190\x02245\x0261\x02112\x021442\x021012\x02409\x021819\x022592\x02132\x02293\x02274\x02125\x02301\x021998\x02160\x02537\x022447\x021205\x02290\x021806\x02252\x02579\x02260\x02436\x02229\x021180\x02239\x02997\x02209\x02482\x021585\x02306\x02111\x02428\x02478\x02120\x02318\x021460\x0296\x0266\x02323\x02117\x02188\x027\x02250\x022589\x02583\x0260\x02100\x02659\x0219\x0275\x022169\x0248\x02122\x02137\x02157\x022899\x02153\x0249\x02119\x02841\x02104\x02859\x021835\x02331\x0295\x02541\x02314\x0253\x021756\x024\x021083\x02514\x02468\x022025\x02727\x0237\x02206\x02668\x02175\x02272\x02395\x028\x02381\x02199\x02472\x02116\x021392\x025\x0288\x0290\x02321\x0245\x02162\x02201\x02924\x02292\x022454\x02432\x0242\x02213\x021281\x026\x021892\x02434\x02486\x02729\x02477\x022606\x02756\x022412\x02138\x021105\x02800\x02543\x022\x02166\x02227\x021008\x02390\x0282\x02611\x0244\x02275\x021321\x02237\x0294\x02224\x02118\x0281\x02654\x021\x02488\x021678\x02212\x0212\x0221\x021971\x02416\x02279\x02387\x02211\x0280\x02531\x02113\x0213\x0292\x021617\x0214\x02695\x02265\x0238\x02101\x0216\x02278\x02156\x0218\x023\x02362\x02198\x0223\x02655\x02123\x021640\x021045\x02804\x02305\x02577\x022625'],
#        ['13024',
#         '76\x02124\x02360\x0273\x021701\x02155\x02455\x02980\x02112\x021912\x02953\x02209\x0277\x021583\x022324\x02117\x02151\x02626\x0287\x022080\x02642\x02126\x02104\x02271\x0247\x02692\x02127\x0253\x02738\x024\x02307\x02834\x025\x0288\x02791\x022\x0264\x021122\x02425\x02187\x02616\x02237\x0286\x0281\x021\x02567\x0212\x0280\x021604\x02516\x0289\x0215\x021629\x0214\x0225\x02571\x023\x02241\x022467\x02230\x0223']],
#       dtype='<U2725')

# %%
len(set(ug.user.values))
# Out:
# 13024

# %%
len(set(ul.user.values))
# Out:
# 10592

# %%
# item feat

# %%
bp.shape
# Out:
# (21773, 2)

# %%
ba.shape
# Out:
# (21907, 2)

# %%
ba.book.shape
# Out:
# (21907,)

# %%
len(set(ba.book.values))
# Out:
# 21907

# %%
bp.shape
# Out:
# (21773, 2)

# %%
len(set(bp.book.values))
# Out:
# 21773

# %%
len(set(by.book.values))
# Out:
# 21192

# %%
by.book.shape
# Out:
# (21192,)

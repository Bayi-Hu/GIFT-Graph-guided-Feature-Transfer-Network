# %%
ls ../data/
# Out:
# cat_voc.pkl              local_train_splitByUser  uid_voc.pkl
# local_test_splitByUser   mid_voc.pkl

# %%
import pickle as pkl

# %%
train_file = "../data/local_train_splitByUser"

# %%
with open("") as f:
